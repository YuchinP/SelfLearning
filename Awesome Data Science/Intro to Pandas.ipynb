# %% [markdown]
# ## Preliminaries

# %%
# load libraries and set styles, options
import warnings; warnings.simplefilter('ignore')


import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib; matplotlib.style.use('ggplot')

from pandas import set_option
set_option("display.max_rows", 16)

LARGE_FIGSIZE = (12, 8)

from ipywidgets import interact

# %%
#inline plots
# %matplotlib inline

# %% [markdown]
# ## Read and verify data

# %%
# read csv dataset and load into pandas dataframe object "lexp"
lexp = pd.read_csv('lexpectancy.csv')

# %%
#check first few lines
lexp.head()
# Out:
#        Country Code       1960       1961       1962       1963       1964  \
# 0        Aruba  ABW  65.569366  65.988024  66.365537  66.713976  67.044293
# 1      Andorra  AND        NaN        NaN        NaN        NaN        NaN
# 2  Afghanistan  AFG  32.328512  32.777439  33.219902  33.657878  34.092878
# 3       Angola  AGO  32.984829  33.386220  33.787585  34.188463  34.590341
# 4      Albania  ALB  62.254366  63.273463  64.162854  64.887098  65.438195
#
#         1965       1966       1967    ...           2004       2005  \
# 0  67.369756  67.699000  68.034683    ...      74.090854  74.228073
# 1        NaN        NaN        NaN    ...            NaN        NaN
# 2  34.525390  34.957415  35.389415    ...      56.626317  57.027244
# 3  34.992220  35.395098  35.799976    ...      48.003512  48.538805
# 4  65.827390  66.089317  66.287220    ...      75.839000  76.089390
#
#         2006       2007       2008       2009       2010       2011  \
# 0  74.376195  74.526756  74.675732  74.818146  74.953537  75.081390
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2  57.432561  57.833829  58.225024  58.603683  58.970829  59.327951
# 3  49.007049  49.435732  49.847390  50.251024  50.654171  51.059317
# 4  76.290537  76.464854  76.632317  76.801878  76.978512  77.163220
#
#         2012       2013
# 0  75.205756  75.328659
# 1        NaN        NaN
# 2  59.679610  60.028268
# 3  51.464000  51.866171
# 4  77.350463  77.537244
#
# [5 rows x 56 columns]

# %%
#verify dataframe shape
lexp.shape
# Out:
# (248, 56)

# %%
#review dataframe info
lexp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 56 columns):
# Country    248 non-null object
# Code       248 non-null object
# 1960       222 non-null float64
# 1961       223 non-null float64
# 1962       223 non-null float64
# 1963       222 non-null float64
# 1964       222 non-null float64
# 1965       223 non-null float64
# 1966       223 non-null float64
# 1967       223 non-null float64
# 1968       223 non-null float64
# 1969       223 non-null float64
# 1970       224 non-null float64
# 1971       223 non-null float64
# 1972       223 non-null float64
# 1973       224 non-null float64
# 1974       223 non-null float64
# 1975       223 non-null float64
# 1976       223 non-null float64
# 1977       223 non-null float64
# 1978       225 non-null float64
# 1979       224 non-null float64
# 1980       225 non-null float64
# 1981       225 non-null float64
# 1982       229 non-null float64
# 1983       226 non-null float64
# 1984       226 non-null float64
# 1985       226 non-null float64
# 1986       227 non-null float64
# 1987       231 non-null float64
# 1988       227 non-null float64
# 1989       227 non-null float64
# 1990       229 non-null float64
# 1991       230 non-null float64
# 1992       231 non-null float64
# 1993       228 non-null float64
# 1994       230 non-null float64
# 1995       230 non-null float64
# 1996       230 non-null float64
# 1997       234 non-null float64
# 1998       230 non-null float64
# 1999       231 non-null float64
# 2000       234 non-null float64
# 2001       232 non-null float64
# 2002       236 non-null float64
# 2003       233 non-null float64
# 2004       233 non-null float64
# 2005       234 non-null float64
# 2006       234 non-null float64
# 2007       235 non-null float64
# 2008       235 non-null float64
# 2009       235 non-null float64
# 2010       233 non-null float64
# 2011       234 non-null float64
# 2012       231 non-null float64
# 2013       231 non-null float64
# dtypes: float64(54), object(2)
# memory usage: 108.6+ KB

# %%
#set dataframe row index to country
lexp = lexp.set_index('Country')

# %%
lexp.head()
# Out:
#             Code       1960       1961       1962       1963       1964  \
# Country
# Aruba        ABW  65.569366  65.988024  66.365537  66.713976  67.044293
# Andorra      AND        NaN        NaN        NaN        NaN        NaN
# Afghanistan  AFG  32.328512  32.777439  33.219902  33.657878  34.092878
# Angola       AGO  32.984829  33.386220  33.787585  34.188463  34.590341
# Albania      ALB  62.254366  63.273463  64.162854  64.887098  65.438195
#
#                   1965       1966       1967       1968    ...           2004  \
# Country                                                    ...
# Aruba        67.369756  67.699000  68.034683  68.377146    ...      74.090854
# Andorra            NaN        NaN        NaN        NaN    ...            NaN
# Afghanistan  34.525390  34.957415  35.389415  35.822415    ...      56.626317
# Angola       34.992220  35.395098  35.799976  36.205854    ...      48.003512
# Albania      65.827390  66.089317  66.287220  66.474951    ...      75.839000
#
#                   2005       2006       2007       2008       2009       2010  \
# Country
# Aruba        74.228073  74.376195  74.526756  74.675732  74.818146  74.953537
# Andorra            NaN        NaN        NaN        NaN        NaN        NaN
# Afghanistan  57.027244  57.432561  57.833829  58.225024  58.603683  58.970829
# Angola       48.538805  49.007049  49.435732  49.847390  50.251024  50.654171
# Albania      76.089390  76.290537  76.464854  76.632317  76.801878  76.978512
#
#                   2011       2012       2013
# Country
# Aruba        75.081390  75.205756  75.328659
# Andorra            NaN        NaN        NaN
# Afghanistan  59.327951  59.679610  60.028268
# Angola       51.059317  51.464000  51.866171
# Albania      77.163220  77.350463  77.537244
#
# [5 rows x 55 columns]

# %% [markdown]
# The country column is not the index rather than the primary key

# %% [markdown]
# ## Initial EDA
# **Did life expectancy increase from 1960 to 2013?**

# %%
lexp.mean().plot()

# %% [markdown]
# ** Which countries had the highest and lowest life expectancy in 1960?**

# %%
# idxman and idxmin provide the indicies corresponding to max and min values in a column
print(lexp['1960'].idxmax())
print(lexp['1960'].idxmin())
# Out:
# Norway
# Mali

# %% [markdown]
# idxmax and idxmin are from pandas. Stands for IndexMaximum and IndexMinimum. Returns countries because we set it to the index.

# %% [markdown]
# **What were the highest, lowest and mean values in 1960**

# %%
#max and min provide the values
print(np.round(lexp['1960'].max()))
print(np.round(lexp['1960'].min()))
print(np.round(lexp['1960'].mean()))
# Out:
# 74.0
# 28.0
# 54.0

# %% [markdown]
# round is from numpy and rounds the output to the nearest specified decimals

# %% [markdown]
# ** What were the highest lowest and mean values for arbitrary year?**

# %%
#define function to display high low and mean for a year
def high_low_mean(year):
    print("In year", year)
    print(lexp[year].idxmax(), "had the highest LE rate of:", np.round(lexp[year].max()))
    print(lexp[year].idxmin(), "had the lowest LE rate of:", np.round(lexp[year].min()))
    print("The mean LE rate was: ", np.round(lexp[year].mean()))

# %%
high_low_mean('2009')
# Out:
# ('In year', '2009')
# ('San Marino', 'had the highest LE rate of:', 83.0)
# ('Lesotho', 'had the lowest LE rate of:', 47.0)
# ('The mean LE rate was: ', 70.0)

# %% [markdown]
# **Which countries had the highest and lowest gains in life expectancy**

# %%
# calculate gain and attach to a new column; gain = (value_in_2013 - value_in_1960/value_in_1960
lexp['gain'] = pd.Series.round((lexp['2013']-lexp['1960'])/lexp['1960'],2)

# %%
lexp.head()
# Out:
#             Code       1960       1961       1962       1963       1964  \
# Country
# Aruba        ABW  65.569366  65.988024  66.365537  66.713976  67.044293
# Andorra      AND        NaN        NaN        NaN        NaN        NaN
# Afghanistan  AFG  32.328512  32.777439  33.219902  33.657878  34.092878
# Angola       AGO  32.984829  33.386220  33.787585  34.188463  34.590341
# Albania      ALB  62.254366  63.273463  64.162854  64.887098  65.438195
#
#                   1965       1966       1967       1968  ...        2005  \
# Country                                                  ...
# Aruba        67.369756  67.699000  68.034683  68.377146  ...   74.228073
# Andorra            NaN        NaN        NaN        NaN  ...         NaN
# Afghanistan  34.525390  34.957415  35.389415  35.822415  ...   57.027244
# Angola       34.992220  35.395098  35.799976  36.205854  ...   48.538805
# Albania      65.827390  66.089317  66.287220  66.474951  ...   76.089390
#
#                   2006       2007       2008       2009       2010       2011  \
# Country
# Aruba        74.376195  74.526756  74.675732  74.818146  74.953537  75.081390
# Andorra            NaN        NaN        NaN        NaN        NaN        NaN
# Afghanistan  57.432561  57.833829  58.225024  58.603683  58.970829  59.327951
# Angola       49.007049  49.435732  49.847390  50.251024  50.654171  51.059317
# Albania      76.290537  76.464854  76.632317  76.801878  76.978512  77.163220
#
#                   2012       2013  gain
# Country
# Aruba        75.205756  75.328659  0.15
# Andorra            NaN        NaN   NaN
# Afghanistan  59.679610  60.028268  0.86
# Angola       51.464000  51.866171  0.57
# Albania      77.350463  77.537244  0.25
#
# [5 rows x 56 columns]

# %%
#create pandas series object with only the gain column
gain = lexp['gain']

# %%
#verify object type gain
type(gain)
# Out:
# pandas.core.series.Series

# %%
gain.head()
# Out:
# Country
# Aruba          0.15
# Andorra         NaN
# Afghanistan    0.86
# Angola         0.57
# Albania        0.25
# Name: gain, dtype: float64

# %%
#drop missing values and order the series
lexp_gain = gain.dropna().order(ascending=False)

# %%
lexp_gain.head()
# Out:
# Country
# Bhutan         1.14
# Maldives       1.06
# Mali           1.04
# Timor-Leste    1.00
# Nepal          0.97
# Name: gain, dtype: float64

# %%
#ten countries with the most gain
lexp_gain.head(10)
# Out:
# Country
# Bhutan         1.14
# Maldives       1.06
# Mali           1.04
# Timor-Leste    1.00
# Nepal          0.97
# Gambia, The    0.87
# Afghanistan    0.86
# Yemen, Rep.    0.85
# Oman           0.80
# Tunisia        0.75
# Name: gain, dtype: float64

# %%
#ten countries with the least gain
lexp_gain.tail(10)
# Out:
# Country
# Guyana                0.10
# Slovak Republic       0.09
# Zimbabwe              0.08
# Russian Federation    0.08
# Bulgaria              0.08
# Belarus               0.07
# Lesotho               0.06
# Lithuania             0.06
# Latvia                0.06
# Ukraine               0.04
# Name: gain, dtype: float64

# %%
#delete gain column from lexp dataframe since it is now available in lexp_gain
del lexp['gain']

# %%
#historgram of gains
lexp_gain.hist()

# %%
#kde plot of gains
lexp_gain.plot(kind='kde')

# %%
#bar graph of gains and save it to a file
ax = lexp_gain.plot(kind='bar', figsize=(50,25));
fig = ax.get_figure()
fig.savefig('gain.png')

# %% [markdown]
# ## Plots of various distributions

# %% [markdown]
# ### Histograms

# %%
#histogram of LE for a particular year using standard matplotlib and pandas
lexp.hist(column='1960', bins = 20);

# %%
#compare distributions for years 1960 and 2013 in subplots
f, (ax1, ax2) = plt.subplots(2);
lexp.hist(column='1960', ax=ax1);
lexp.hist(column='2013', color='green', ax=ax2)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001060B630>], dtype=object)

# %%
#compare two years in the same frame
f, (ax1) = plt.subplots(1,figsize=LARGE_FIGSIZE)
lexp.hist(column='1960', bins=30, ax=ax1);
lexp.hist(column='2013', bins=30, color = 'blue', ax=ax1);
plt.xlabel('Life Expectancy')
plt.ylabel('Number of Countries')
plt.title("1960 vs 2013")

# %%
# define function to compare two years in the same frame
def compare_hist(year1,year2):
    f, (ax1) = plt.subplots(1,figsize=LARGE_FIGSIZE)
    lexp.hist(column=year1,bins=20, ax=ax1);
    lexp.hist(column=year2,bins=20, color='green', ax=ax1)
    plt.xlabel('Life Expectancy')
    plt.ylabel('Number of Countries')
    plt.title(str(year1) + " vs " + str(year2))

# %%
compare_hist('1960', '2010')

# %% [markdown]
# **Create interactive widget to compare decades**

# %%
#use list comprehension to extract decades
years = [str(year) for year in range(1960,2014) if year%10==0]

# %%
years
# Out:
# ['1960', '1970', '1980', '1990', '2000', '2010']

# %%
interact(compare_hist, year1=years, year2=years);

# %% [markdown]
# ### Kernal Densite Estimate (KDE) and Rugplot

# %%
#use seaborn visualization library to plot distributions
#parameters for histogram, kde, and rug can be set to true or false

sns.distplot(lexp['2010'].dropna(), hist = False, kde = True, rug = False, bins = 25)

# %%
def sns_compare(year1,year2):
    f, (ax1) = plt.subplots(1, figsize=LARGE_FIGSIZE)
    for yr in range(int(year1),int(year2)):
        sns.distplot(lexp[str(yr)].dropna(), hist=False, kde=True, rug=False, bins=25)

# %%
sns_compare('2000', '2010')

# %%
#create interactive widget
interact(sns_compare, year1=years, year2=years);

# %%
#side by side comparison
f, (ax1) = plt.subplots(1, figsize=LARGE_FIGSIZE)
sns.distplot(lexp['1960'].dropna(),hist=True, kde=True, rug=False, bins=25);
sns.distplot(lexp['2010'].dropna(),hist=True, kde=True, rug=False, bins=25);
plt.xlabel('Life Expectancy');
plt.ylabel('Number of Countries');
plt.title('Life Expectancy: 1960 vs 2010')

# %%
#facetgrid version kdeplot by decade
fig = sns.FacetGrid(lexp,aspect=4)
decades = [str(year) for year in range (1960,2000) if year%10==0]
for year in decades:
    fig.map(sns.kdeplot, year, color=np.random.rand(3,1))

# %% [markdown]
# **Boxplot**

# %%
#boxplot using standard pandas and matplotlib
lexp.boxplot(column='1960');

# %%
lexp.boxplot(column=['1960', '2010']);

# %%
def boxplot_compare(year1, year2):
    f, (ax1) = plt.subplots(1, figsize = LARGE_FIGSIZE)
    lexp.boxplot(column=[year1, year2]);

# %%
interact(boxplot_compare, year1=years, year2=years);

# %% [markdown]
# **Violinplot**

# %%
sns.violinplot(lexp['1960'])

# %%
sns.violinplot(lexp['1960'], palette="Set2",linewidth=5)
sns.violinplot(lexp['2010'],linewidth=5)

# %%
def violin_compare(year1,year2):
    f, (ax1) = plt.subplots(1, figsize = LARGE_FIGSIZE)
    sns.violinplot(lexp[year1], palette="Set2")
    sns.violinplot(lexp[year2])

# %%
interact(violin_compare, year1=years, year2=years);

# %% [markdown]
# ## Insight and Discovery

# %%
lexp.head()
# Out:
#             Code       1960       1961       1962       1963       1964  \
# Country
# Aruba        ABW  65.569366  65.988024  66.365537  66.713976  67.044293
# Andorra      AND        NaN        NaN        NaN        NaN        NaN
# Afghanistan  AFG  32.328512  32.777439  33.219902  33.657878  34.092878
# Angola       AGO  32.984829  33.386220  33.787585  34.188463  34.590341
# Albania      ALB  62.254366  63.273463  64.162854  64.887098  65.438195
#
#                   1965       1966       1967       1968    ...           2004  \
# Country                                                    ...
# Aruba        67.369756  67.699000  68.034683  68.377146    ...      74.090854
# Andorra            NaN        NaN        NaN        NaN    ...            NaN
# Afghanistan  34.525390  34.957415  35.389415  35.822415    ...      56.626317
# Angola       34.992220  35.395098  35.799976  36.205854    ...      48.003512
# Albania      65.827390  66.089317  66.287220  66.474951    ...      75.839000
#
#                   2005       2006       2007       2008       2009       2010  \
# Country
# Aruba        74.228073  74.376195  74.526756  74.675732  74.818146  74.953537
# Andorra            NaN        NaN        NaN        NaN        NaN        NaN
# Afghanistan  57.027244  57.432561  57.833829  58.225024  58.603683  58.970829
# Angola       48.538805  49.007049  49.435732  49.847390  50.251024  50.654171
# Albania      76.089390  76.290537  76.464854  76.632317  76.801878  76.978512
#
#                   2011       2012       2013
# Country
# Aruba        75.081390  75.205756  75.328659
# Andorra            NaN        NaN        NaN
# Afghanistan  59.327951  59.679610  60.028268
# Angola       51.059317  51.464000  51.866171
# Albania      77.163220  77.350463  77.537244
#
# [5 rows x 55 columns]

# %%
#transform the lexp dataframe
transform = lexp.T

# %%
transform.head()
# Out:
# Country    Aruba Andorra Afghanistan   Angola  Albania Arab World  \
# Code         ABW     AND         AFG      AGO      ALB        ARB
# 1960     65.5694     NaN     32.3285  32.9848  62.2544    46.8471
# 1961      65.988     NaN     32.7774  33.3862  63.2735    47.4276
# 1962     66.3655     NaN     33.2199  33.7876  64.1629    48.0072
# 1963      66.714     NaN     33.6579  34.1885  64.8871    48.5895
#
# Country United Arab Emirates Argentina  Armenia American Samoa   ...     \
# Code                     ARE       ARG      ARM            ASM   ...
# 1960                 52.2432   65.2155  65.8635            NaN   ...
# 1961                 53.2866   65.3385  66.2844            NaN   ...
# 1962                  54.327   65.4326  66.7099            NaN   ...
# 1963                 55.3635   65.5094  67.1379            NaN   ...
#
# Country  Vietnam  Vanuatu West Bank and Gaza    World    Samoa Yemen, Rep.  \
# Code         VNM      VUT                PSE      WLD      WSM         YEM
# 1960      59.067  46.4875                NaN  52.4998  49.9695     34.3638
# 1961     59.7442  47.0881                NaN  53.0044  50.4695     34.4732
# 1962     60.4105  47.6882                NaN  53.4718  50.9695     34.7396
# 1963      61.043  48.2873                NaN  54.0974  51.4695     35.1868
#
# Country South Africa Congo, Dem. Rep.   Zambia Zimbabwe
# Code             ZAF              COD      ZMB      ZWE
# 1960         49.0363           41.018  45.1098  51.5425
# 1961         49.4298          41.2335  45.4875   51.915
# 1962         49.8133          41.4515  45.8537  52.2779
# 1963         50.1958           41.678  46.2087  52.6293
#
# [5 rows x 248 columns]

# %%
#drop the country code row
t = transform.ix[1:]

# %%
#verify first few lines
t.head()
# Out:
# Country    Aruba Andorra Afghanistan   Angola  Albania Arab World  \
# 1960     65.5694     NaN     32.3285  32.9848  62.2544    46.8471
# 1961      65.988     NaN     32.7774  33.3862  63.2735    47.4276
# 1962     66.3655     NaN     33.2199  33.7876  64.1629    48.0072
# 1963      66.714     NaN     33.6579  34.1885  64.8871    48.5895
# 1964     67.0443     NaN     34.0929  34.5903  65.4382    49.1748
#
# Country United Arab Emirates Argentina  Armenia American Samoa   ...     \
# 1960                 52.2432   65.2155  65.8635            NaN   ...
# 1961                 53.2866   65.3385  66.2844            NaN   ...
# 1962                  54.327   65.4326  66.7099            NaN   ...
# 1963                 55.3635   65.5094  67.1379            NaN   ...
# 1964                 56.3926   65.5824  67.5654            NaN   ...
#
# Country  Vietnam  Vanuatu West Bank and Gaza    World    Samoa Yemen, Rep.  \
# 1960      59.067  46.4875                NaN  52.4998  49.9695     34.3638
# 1961     59.7442  47.0881                NaN  53.0044  50.4695     34.4732
# 1962     60.4105  47.6882                NaN  53.4718  50.9695     34.7396
# 1963      61.043  48.2873                NaN  54.0974  51.4695     35.1868
# 1964     61.6071  48.8868                NaN   54.913  51.9695     35.8129
#
# Country South Africa Congo, Dem. Rep.   Zambia Zimbabwe
# 1960         49.0363           41.018  45.1098  51.5425
# 1961         49.4298          41.2335  45.4875   51.915
# 1962         49.8133          41.4515  45.8537  52.2779
# 1963         50.1958           41.678  46.2087  52.6293
# 1964         50.5818           41.918  46.5577  52.9717
#
# [5 rows x 248 columns]

# %%
#compare life expectancy
#Norway had highest life expectancy in 1960
t['Norway'].plot()

#Mali had lowest life expectancy in 1960
t['Mali'].plot()

plt.legend();

# %%
print("Norway Percentage Gain = ", lexp_gain['Norway'])
print("Mali Percentage Gain = ", lexp_gain['Mali'])
# Out:
# ('Norway Percentage Gain = ', 0.11)
# ('Mali Percentage Gain = ', 1.04)

# %% [markdown]
# ### Visual representation of life expectancy during period 1960-2013

# %%
#birds eye view of LE
fig = plt.figure(figsize = LARGE_FIGSIZE)
lexp.boxplot(sym="*");
plt.xticks(rotation='vertical');

# %%
lexp['1977'].idxmin()
# Out:
# 'Cambodia'

# %%
lexp['1993'].idxmin()
# Out:
# 'Rwanda'

# %%
fig = plt.figure(figsize=(20,10), dpi=200)
t['Cambodia'].plot(marker='o', color = 'blue');
t['Rwanda'].plot(marker='o', color = 'green');
lexp.mean().plot(color='red', label = 'Mean');
plt.xticks(rotation = 'vertical');
plt.legend();

# %% [markdown]
# ### Compare sets of countries

# %%
#define function to compare a set of countries; the comparison prints gain percentage and plot of LE
def compare(countries):
    for country in countries:
        t[country].plot(figsize = (20,10))
        print(country, lexp_gain[country])
    plt.legend();

# %%
#create a list of ten countries with lowest life expectancy in 1960
bot10 = lexp.sort_values(by='1960')['1960'].head(10).index.tolist()

# %%
#create a list of ten countries with highest life expectancy in 1960
top10 = lexp.sort_values(by='1960')['1960'].dropna().tail(10).index.tolist()

# %%
bot10
# Out:
# ['Mali',
#  'Sierra Leone',
#  'South Sudan',
#  'Gambia, The',
#  'Afghanistan',
#  'Bhutan',
#  'Angola',
#  'Timor-Leste',
#  'Yemen, Rep.',
#  'Burkina Faso']

# %%
compare(bot10)
# Out:
# ('Mali', 1.04)
# ('Sierra Leone', 0.66000000000000003)
# ('South Sudan', 0.73999999999999999)
# ('Gambia, The', 0.87)
# ('Afghanistan', 0.85999999999999999)
# ('Bhutan', 1.1399999999999999)
# ('Angola', 0.56999999999999995)
# ('Timor-Leste', 1.0)
# ('Yemen, Rep.', 0.84999999999999998)
# ('Burkina Faso', 0.68999999999999995)

# %%
compare(top10)
# Out:
# ('Australia', 0.16)
# ('United Kingdom', 0.14000000000000001)
# ('Canada', 0.14000000000000001)
# ('New Zealand', 0.14000000000000001)
# ('Switzerland', 0.16)
# ('Denmark', 0.11)
# ('Sweden', 0.12)
# ('Netherlands', 0.11)
# ('Iceland', 0.13)
# ('Norway', 0.11)

# %%
sub_sahara=['Namibia','Botswana','South Africa','Uganda','Kenya']

# %%
compare(sub_sahara)
# Out:
# ('Namibia', 0.37)
# ('Botswana', 0.27000000000000002)
# ('South Africa', 0.16)
# ('Uganda', 0.31)
# ('Kenya', 0.31)

# %%
latam = ['Argentina','Bolivia','Colombia','Chile','Brazil','Paraguay','Uruguay']

# %%
compare(latam)
# Out:
# ('Argentina', 0.17000000000000001)
# ('Bolivia', 0.60999999999999999)
# ('Colombia', 0.29999999999999999)
# ('Chile', 0.40999999999999998)
# ('Brazil', 0.37)
# ('Paraguay', 0.14000000000000001)
# ('Uruguay', 0.13)

# %%
africa = ['Nigeria','South Africa','Niger','Tanzania','Zambia']

# %%
compare(afr)
